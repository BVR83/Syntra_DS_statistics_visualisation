# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulated data
data = [1101.1319623322559, 965.5162483920343, 1154.3912030145648, 0, 1072.2890771655877, 849.3374169533315, 1005.488163829657, 0, 960.6317211235362]

# Remove any zeros from the data (if needed)
data = [x for x in data if x != 0]

# Define the cumulative distribution function
def cumulative_distribution_function(x):
    sorted_data = np.sort(data)
    n = len(sorted_data)
    cdf = np.searchsorted(sorted_data, x, side='right') / n
    return cdf

# Generate x values from 0 to 10^4
xx = np.linspace(min(data), max(data))

# Calculate the CDF values for the generated x values
Fxx = cumulative_distribution_function(xx)

# Plot the CDF
plt.plot(xx, Fxx)
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.title('Empirical Cumulative Distribution Function (ECDF)')
plt.grid(True)
plt.show()
